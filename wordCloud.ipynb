# %% [markdown]
# Author: Elaine da Silva
# Date: March 2025
# Purpose: provide a world cloud based on celebrations.csv file

# %%
# Pacotes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('celebrations.csv', delimiter=';')

# %%
# Gather the words from job description and concatenate all rows in a string
text = ' '.join(df.celebrations.astype(str))

# %%
# remove the stopswords
stopwords = set(STOPWORDS)  # Patterns stopwords
stopwords = stopwords.update(['using', 'across', 'end', 'and', 'to', 'level', 'at all', 'within', 'with', 'well', 'able', 'make', 'in', '.', 'on', 'at', ' a ', 'of', 'for','an'])

# %%
# Generate the wordcloud
wordCloud = WordCloud(
    background_color='orange',
    width=800,
    height=400,
    stopwords=stopwords
).generate( text )

# %%
# visualize the wordcloud
fig, ax = plt.subplots( figsize=(10, 7) )
ax.imshow( wordCloud, interpolation='bilinear' )
ax.set_axis_off()

# %%
# 5. Salvar a imagem como PNG
wordCloud.to_file('wordcloud_orange_pq.png')
